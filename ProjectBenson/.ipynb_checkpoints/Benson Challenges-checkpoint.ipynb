# %%
# !head -1000 turnstile_160109.csv > turnshort.csv
#shortens the file so it loads easier. bless up

# %%
#challenge 1

import pandas as pd
import datetime
data = pd.read_csv("turnshort.csv", header=0)

data['key'] = list(zip(data['C/A'], data['UNIT'], data['SCP'], data['STATION']))
#print(list(zip(data['C/A'], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}
#print(data)

# %%
#Challenge 2
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)


data['key'] = list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

data['datetime'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
datetime_dict = {}

for index, row in data.iterrows():
	value = row['datetime'], row['ENTRIES']
	key = row['key']

	if key in datetime_dict:
		datetime_dict[key].append(value)

	else:
		datetime_dict[key] = [value]

def days(my_list):
	dates = [row[0].date() for row in my_list]
	dates = set(dates)

	result = []
	for date in dates:
		entries = [x[1] for x in my_list if x[0].date () == date]
		result.append((date, max(entries)-min(entries)))

	return result

count_dict = {key:days(datetime_dict[key]) for key in datetime_dict}
#pprint.pprint(count_dict, width = 100)

# %%
#Challenge 2
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)

data['key'] = list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

# %%
data
# Out:
#       C/A  UNIT       SCP     STATION LINENAME DIVISION        DATE      TIME  \
# 0    A002  R051  02-00-00       59 ST   NQR456      BMT  01/02/2016  03:00:00
# 1    A002  R051  02-00-00       59 ST   NQR456      BMT  01/02/2016  07:00:00
# 2    A002  R051  02-00-00       59 ST   NQR456      BMT  01/02/2016  11:00:00
# 3    A002  R051  02-00-00       59 ST   NQR456      BMT  01/02/2016  15:00:00
# 4    A002  R051  02-00-00       59 ST   NQR456      BMT  01/02/2016  19:00:00
# 5    A002  R051  02-00-00       59 ST   NQR456      BMT  01/02/2016  23:00:00
# 6    A002  R051  02-00-00       59 ST   NQR456      BMT  01/03/2016  03:00:00
# 7    A002  R051  02-00-00       59 ST   NQR456      BMT  01/03/2016  07:00:00
# 8    A002  R051  02-00-00       59 ST   NQR456      BMT  01/03/2016  11:00:00
# 9    A002  R051  02-00-00       59 ST   NQR456      BMT  01/03/2016  15:00:00
# 10   A002  R051  02-00-00       59 ST   NQR456      BMT  01/03/2016  19:00:00
# 11   A002  R051  02-00-00       59 ST   NQR456      BMT  01/03/2016  23:00:00
# 12   A002  R051  02-00-00       59 ST   NQR456      BMT  01/04/2016  03:00:00
# 13   A002  R051  02-00-00       59 ST   NQR456      BMT  01/04/2016  07:00:00
# 14   A002  R051  02-00-00       59 ST   NQR456      BMT  01/04/2016  11:00:00
# 15   A002  R051  02-00-00       59 ST   NQR456      BMT  01/04/2016  15:00:00
# 16   A002  R051  02-00-00       59 ST   NQR456      BMT  01/04/2016  19:00:00
# 17   A002  R051  02-00-00       59 ST   NQR456      BMT  01/04/2016  23:00:00
# 18   A002  R051  02-00-00       59 ST   NQR456      BMT  01/05/2016  03:00:00
# 19   A002  R051  02-00-00       59 ST   NQR456      BMT  01/05/2016  07:00:00
# 20   A002  R051  02-00-00       59 ST   NQR456      BMT  01/05/2016  11:00:00
# 21   A002  R051  02-00-00       59 ST   NQR456      BMT  01/05/2016  15:00:00
# 22   A002  R051  02-00-00       59 ST   NQR456      BMT  01/05/2016  19:00:00
# 23   A002  R051  02-00-00       59 ST   NQR456      BMT  01/05/2016  23:00:00
# 24   A002  R051  02-00-00       59 ST   NQR456      BMT  01/06/2016  03:00:00
# 25   A002  R051  02-00-00       59 ST   NQR456      BMT  01/06/2016  07:00:00
# 26   A002  R051  02-00-00       59 ST   NQR456      BMT  01/06/2016  11:00:00
# 27   A002  R051  02-00-00       59 ST   NQR456      BMT  01/06/2016  15:00:00
# 28   A002  R051  02-00-00       59 ST   NQR456      BMT  01/06/2016  19:00:00
# 29   A002  R051  02-00-00       59 ST   NQR456      BMT  01/06/2016  23:00:00
# ..    ...   ...       ...         ...      ...      ...         ...       ...
# 969  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/02/2016  17:00:00
# 970  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/02/2016  21:00:00
# 971  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/03/2016  01:00:00
# 972  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/03/2016  05:00:00
# 973  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/03/2016  09:00:00
# 974  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/03/2016  13:00:00
# 975  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/03/2016  17:00:00
# 976  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/03/2016  21:00:00
# 977  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/04/2016  01:00:00
# 978  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/04/2016  05:00:00
# 979  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/04/2016  09:00:00
# 980  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/04/2016  13:00:00
# 981  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/04/2016  17:00:00
# 982  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/04/2016  21:00:00
# 983  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/05/2016  01:00:00
# 984  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/05/2016  05:00:00
# 985  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/05/2016  09:00:00
# 986  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/05/2016  13:00:00
# 987  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/05/2016  17:00:00
# 988  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/05/2016  21:00:00
# 989  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/06/2016  01:00:00
# 990  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/06/2016  05:00:00
# 991  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/06/2016  09:00:00
# 992  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/06/2016  13:00:00
# 993  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/06/2016  17:00:00
# 994  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/06/2016  21:00:00
# 995  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/07/2016  01:00:00
# 996  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/07/2016  05:00:00
# 997  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/07/2016  09:00:00
# 998  A007  R079  01-06-01  5 AV/59 ST      NQR      BMT  01/07/2016  13:00:00
#
#         DESC    ENTRIES  \
# 0    REGULAR    5478180
# 1    REGULAR    5478183
# 2    REGULAR    5478262
# 3    REGULAR    5478519
# 4    REGULAR    5478940
# 5    REGULAR    5479213
# 6    REGULAR    5479279
# 7    REGULAR    5479282
# 8    REGULAR    5479344
# 9    REGULAR    5479558
# 10   REGULAR    5479861
# 11   REGULAR    5480016
# 12   REGULAR    5480037
# 13   REGULAR    5480054
# 14   REGULAR    5480267
# 15   REGULAR    5480499
# 16   REGULAR    5481461
# 17   REGULAR    5481770
# 18   REGULAR    5481795
# 19   REGULAR    5481808
# 20   REGULAR    5481983
# 21   REGULAR    5482235
# 22   REGULAR    5483044
# 23   REGULAR    5483391
# 24   REGULAR    5483436
# 25   REGULAR    5483458
# 26   REGULAR    5483626
# 27   REGULAR    5483826
# 28   REGULAR    5484778
# 29   REGULAR    5485169
# ..       ...        ...
# 969  REGULAR  117728473
# 970  REGULAR  117728995
# 971  REGULAR  117729165
# 972  REGULAR  117729185
# 973  REGULAR  117729210
# 974  REGULAR  117729256
# 975  REGULAR  117729534
# 976  REGULAR  117729866
# 977  REGULAR  117730012
# 978  REGULAR  117730017
# 979  REGULAR  117730055
# 980  REGULAR  117730181
# 981  REGULAR  117730595
# 982  REGULAR  117731254
# 983  REGULAR  117731425
# 984  REGULAR  117731429
# 985  REGULAR  117731465
# 986  REGULAR  117731564
# 987  REGULAR  117731948
# 988  REGULAR  117732486
# 989  REGULAR  117732629
# 990  REGULAR  117732639
# 991  REGULAR  117732670
# 992  REGULAR  117732763
# 993  REGULAR  117733240
# 994  REGULAR  117733887
# 995  REGULAR  117734077
# 996  REGULAR  117734085
# 997  REGULAR  117734130
# 998  REGULAR  117734249
#
#      EXITS                                                                 \
# 0                                              1849152
# 1                                              1849161
# 2                                              1849240
# 3                                              1849340
# 4                                              1849403
# 5                                              1849445
# 6                                              1849457
# 7                                              1849465
# 8                                              1849513
# 9                                              1849581
# 10                                             1849627
# 11                                             1849650
# 12                                             1849659
# 13                                             1849688
# 14                                             1849999
# 15                                             1850089
# 16                                             1850166
# 17                                             1850206
# 18                                             1850213
# 19                                             1850251
# 20                                             1850609
# 21                                             1850679
# 22                                             1850779
# 23                                             1850820
# 24                                             1850827
# 25                                             1850865
# 26                                             1851260
# 27                                             1851348
# 28                                             1851442
# 29                                             1851501
# ..                                                 ...
# 969                                             512663
# 970                                             513072
# 971                                             513184
# 972                                             513198
# 973                                             513289
# 974                                             513667
# 975                                             514314
# 976                                             514563
# 977                                             514619
# 978                                             514620
# 979                                             515102
# 980                                             515775
# 981                                             516284
# 982                                             516554
# 983                                             516630
# 984                                             516634
# 985                                             517137
# 986                                             517865
# 987                                             518297
# 988                                             518508
# 989                                             518581
# 990                                             518596
# 991                                             519017
# 992                                             519714
# 993                                             520137
# 994                                             520412
# 995                                             520473
# 996                                             520477
# 997                                             520984
# 998                                             521634
#
#                                     key
# 0         (A002, R051, 02-00-00, 59 ST)
# 1         (A002, R051, 02-00-00, 59 ST)
# 2         (A002, R051, 02-00-00, 59 ST)
# 3         (A002, R051, 02-00-00, 59 ST)
# 4         (A002, R051, 02-00-00, 59 ST)
# 5         (A002, R051, 02-00-00, 59 ST)
# 6         (A002, R051, 02-00-00, 59 ST)
# 7         (A002, R051, 02-00-00, 59 ST)
# 8         (A002, R051, 02-00-00, 59 ST)
# 9         (A002, R051, 02-00-00, 59 ST)
# 10        (A002, R051, 02-00-00, 59 ST)
# 11        (A002, R051, 02-00-00, 59 ST)
# 12        (A002, R051, 02-00-00, 59 ST)
# 13        (A002, R051, 02-00-00, 59 ST)
# 14        (A002, R051, 02-00-00, 59 ST)
# 15        (A002, R051, 02-00-00, 59 ST)
# 16        (A002, R051, 02-00-00, 59 ST)
# 17        (A002, R051, 02-00-00, 59 ST)
# 18        (A002, R051, 02-00-00, 59 ST)
# 19        (A002, R051, 02-00-00, 59 ST)
# 20        (A002, R051, 02-00-00, 59 ST)
# 21        (A002, R051, 02-00-00, 59 ST)
# 22        (A002, R051, 02-00-00, 59 ST)
# 23        (A002, R051, 02-00-00, 59 ST)
# 24        (A002, R051, 02-00-00, 59 ST)
# 25        (A002, R051, 02-00-00, 59 ST)
# 26        (A002, R051, 02-00-00, 59 ST)
# 27        (A002, R051, 02-00-00, 59 ST)
# 28        (A002, R051, 02-00-00, 59 ST)
# 29        (A002, R051, 02-00-00, 59 ST)
# ..                                  ...
# 969  (A007, R079, 01-06-01, 5 AV/59 ST)
# 970  (A007, R079, 01-06-01, 5 AV/59 ST)
# 971  (A007, R079, 01-06-01, 5 AV/59 ST)
# 972  (A007, R079, 01-06-01, 5 AV/59 ST)
# 973  (A007, R079, 01-06-01, 5 AV/59 ST)
# 974  (A007, R079, 01-06-01, 5 AV/59 ST)
# 975  (A007, R079, 01-06-01, 5 AV/59 ST)
# 976  (A007, R079, 01-06-01, 5 AV/59 ST)
# 977  (A007, R079, 01-06-01, 5 AV/59 ST)
# 978  (A007, R079, 01-06-01, 5 AV/59 ST)
# 979  (A007, R079, 01-06-01, 5 AV/59 ST)
# 980  (A007, R079, 01-06-01, 5 AV/59 ST)
# 981  (A007, R079, 01-06-01, 5 AV/59 ST)
# 982  (A007, R079, 01-06-01, 5 AV/59 ST)
# 983  (A007, R079, 01-06-01, 5 AV/59 ST)
# 984  (A007, R079, 01-06-01, 5 AV/59 ST)
# 985  (A007, R079, 01-06-01, 5 AV/59 ST)
# 986  (A007, R079, 01-06-01, 5 AV/59 ST)
# 987  (A007, R079, 01-06-01, 5 AV/59 ST)
# 988  (A007, R079, 01-06-01, 5 AV/59 ST)
# 989  (A007, R079, 01-06-01, 5 AV/59 ST)
# 990  (A007, R079, 01-06-01, 5 AV/59 ST)
# 991  (A007, R079, 01-06-01, 5 AV/59 ST)
# 992  (A007, R079, 01-06-01, 5 AV/59 ST)
# 993  (A007, R079, 01-06-01, 5 AV/59 ST)
# 994  (A007, R079, 01-06-01, 5 AV/59 ST)
# 995  (A007, R079, 01-06-01, 5 AV/59 ST)
# 996  (A007, R079, 01-06-01, 5 AV/59 ST)
# 997  (A007, R079, 01-06-01, 5 AV/59 ST)
# 998  (A007, R079, 01-06-01, 5 AV/59 ST)
#
# [999 rows x 12 columns]

# %%
#Challenge 3
# n = 4
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)


data['key'] = list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

data['datetime'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
datetime_dict = {}

for index, row in data.iterrows():
	value = row['datetime'], row['ENTRIES']
	key = row['key']

	if key in datetime_dict:
		datetime_dict[key].append(value)

	else:
		datetime_dict[key] = [value]

def CountEachDay(my_list):
	dates = [row[0].date() for row in my_list]
	dates = set(dates)

	result = []
	for date in dates:
		entries = [x[1] for x in my_list if x[0].date () == date]
		result.append((date, max(entries)-min(entries)))

	return result

count_dict = {key:CountEachDay(datetime_dict[key]) for key in datetime_dict}
pprint.pprint(count_dict, width = 100)
# Out:
# {('A002', 'R051', '02-00-00', '59 ST'): [(datetime.date(2016, 1, 5), 1596),
#                                          (datetime.date(2016, 1, 7), 1783),
#                                          (datetime.date(2016, 1, 2), 1033),
#                                          (datetime.date(2016, 1, 6), 1733),
#                                          (datetime.date(2016, 1, 3), 737),
#                                          (datetime.date(2016, 1, 4), 1733),
#                                          (datetime.date(2016, 1, 8), 1853)],
#  ('A002', 'R051', '02-00-01', '59 ST'): [(datetime.date(2016, 1, 5), 1423),
#                                          (datetime.date(2016, 1, 7), 1403),
#                                          (datetime.date(2016, 1, 2), 904),
#                                          (datetime.date(2016, 1, 6), 1459),
#                                          (datetime.date(2016, 1, 3), 669),
#                                          (datetime.date(2016, 1, 4), 1508),
#                                          (datetime.date(2016, 1, 8), 1489)],
#  ('A002', 'R051', '02-03-00', '59 ST'): [(datetime.date(2016, 1, 5), 545),
#                                          (datetime.date(2016, 1, 7), 567),
#                                          (datetime.date(2016, 1, 2), 430),
#                                          (datetime.date(2016, 1, 6), 569),
#                                          (datetime.date(2016, 1, 3), 290),
#                                          (datetime.date(2016, 1, 4), 672),
#                                          (datetime.date(2016, 1, 8), 573)],
#  ('A002', 'R051', '02-03-01', '59 ST'): [(datetime.date(2016, 1, 5), 1250),
#                                          (datetime.date(2016, 1, 7), 1328),
#                                          (datetime.date(2016, 1, 2), 991),
#                                          (datetime.date(2016, 1, 6), 1268),
#                                          (datetime.date(2016, 1, 3), 725),
#                                          (datetime.date(2016, 1, 4), 1250),
#                                          (datetime.date(2016, 1, 8), 1338)],
#  ('A002', 'R051', '02-03-02', '59 ST'): [(datetime.date(2016, 1, 5), 1258),
#                                          (datetime.date(2016, 1, 7), 1369),
#                                          (datetime.date(2016, 1, 2), 880),
#                                          (datetime.date(2016, 1, 6), 1393),
#                                          (datetime.date(2016, 1, 3), 657),
#                                          (datetime.date(2016, 1, 4), 1305),
#                                          (datetime.date(2016, 1, 8), 1408)],
#  ('A002', 'R051', '02-03-03', '59 ST'): [(datetime.date(2016, 1, 5), 1252),
#                                          (datetime.date(2016, 1, 7), 1344),
#                                          (datetime.date(2016, 1, 2), 873),
#                                          (datetime.date(2016, 1, 6), 1406),
#                                          (datetime.date(2016, 1, 3), 629),
#                                          (datetime.date(2016, 1, 4), 1455),
#                                          (datetime.date(2016, 1, 8), 1463)],
#  ('A002', 'R051', '02-03-04', '59 ST'): [(datetime.date(2016, 1, 5), 1698),
#                                          (datetime.date(2016, 1, 7), 1730),
#                                          (datetime.date(2016, 1, 2), 1009),
#                                          (datetime.date(2016, 1, 6), 1888),
#                                          (datetime.date(2016, 1, 3), 696),
#                                          (datetime.date(2016, 1, 4), 1780),
#                                          (datetime.date(2016, 1, 8), 1771)],
#  ('A002', 'R051', '02-03-05', '59 ST'): [(datetime.date(2016, 1, 5), 2482),
#                                          (datetime.date(2016, 1, 7), 2775),
#                                          (datetime.date(2016, 1, 2), 1592),
#                                          (datetime.date(2016, 1, 6), 2726),
#                                          (datetime.date(2016, 1, 3), 1347),
#                                          (datetime.date(2016, 1, 4), 2515),
#                                          (datetime.date(2016, 1, 8), 2745)],
#  ('A002', 'R051', '02-03-06', '59 ST'): [(datetime.date(2016, 1, 5), 2263),
#                                          (datetime.date(2016, 1, 7), 2454),
#                                          (datetime.date(2016, 1, 2), 1068),
#                                          (datetime.date(2016, 1, 6), 2388),
#                                          (datetime.date(2016, 1, 3), 854),
#                                          (datetime.date(2016, 1, 4), 2216),
#                                          (datetime.date(2016, 1, 8), 2325)],
#  ('A002', 'R051', '02-05-00', '59 ST'): [(datetime.date(2016, 1, 5), 0),
#                                          (datetime.date(2016, 1, 7), 0),
#                                          (datetime.date(2016, 1, 2), 0),
#                                          (datetime.date(2016, 1, 6), 0),
#                                          (datetime.date(2016, 1, 3), 1),
#                                          (datetime.date(2016, 1, 4), 0),
#                                          (datetime.date(2016, 1, 8), 0)],
#  ('A002', 'R051', '02-05-01', '59 ST'): [(datetime.date(2016, 1, 5), 0),
#                                          (datetime.date(2016, 1, 7), 0),
#                                          (datetime.date(2016, 1, 2), 0),
#                                          (datetime.date(2016, 1, 6), 0),
#                                          (datetime.date(2016, 1, 3), 0),
#                                          (datetime.date(2016, 1, 4), 0),
#                                          (datetime.date(2016, 1, 8), 0)],
#  ('A002', 'R051', '02-06-00', '59 ST'): [(datetime.date(2016, 1, 5), 2174),
#                                          (datetime.date(2016, 1, 7), 2525),
#                                          (datetime.date(2016, 1, 2), 1176),
#                                          (datetime.date(2016, 1, 6), 2444),
#                                          (datetime.date(2016, 1, 3), 932),
#                                          (datetime.date(2016, 1, 4), 2224),
#                                          (datetime.date(2016, 1, 8), 2482)],
#  ('A006', 'R079', '00-00-00', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 1406),
#                                               (datetime.date(2016, 1, 7), 1625),
#                                               (datetime.date(2016, 1, 2), 1116),
#                                               (datetime.date(2016, 1, 6), 1588),
#                                               (datetime.date(2016, 1, 3), 786),
#                                               (datetime.date(2016, 1, 4), 1596),
#                                               (datetime.date(2016, 1, 8), 1633)],
#  ('A006', 'R079', '00-00-01', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 1501),
#                                               (datetime.date(2016, 1, 7), 1585),
#                                               (datetime.date(2016, 1, 2), 1010),
#                                               (datetime.date(2016, 1, 6), 1553),
#                                               (datetime.date(2016, 1, 3), 746),
#                                               (datetime.date(2016, 1, 4), 1613),
#                                               (datetime.date(2016, 1, 8), 1638)],
#  ('A006', 'R079', '00-00-02', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 1340),
#                                               (datetime.date(2016, 1, 7), 1203),
#                                               (datetime.date(2016, 1, 2), 790),
#                                               (datetime.date(2016, 1, 6), 1233),
#                                               (datetime.date(2016, 1, 3), 491),
#                                               (datetime.date(2016, 1, 4), 1299),
#                                               (datetime.date(2016, 1, 8), 1212)],
#  ('A006', 'R079', '00-00-03', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 1543),
#                                               (datetime.date(2016, 1, 7), 1053),
#                                               (datetime.date(2016, 1, 2), 657),
#                                               (datetime.date(2016, 1, 6), 972),
#                                               (datetime.date(2016, 1, 3), 465),
#                                               (datetime.date(2016, 1, 4), 1094),
#                                               (datetime.date(2016, 1, 8), 940)],
#  ('A006', 'R079', '00-00-04', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 650),
#                                               (datetime.date(2016, 1, 7), 952),
#                                               (datetime.date(2016, 1, 2), 668),
#                                               (datetime.date(2016, 1, 6), 1007),
#                                               (datetime.date(2016, 1, 3), 453),
#                                               (datetime.date(2016, 1, 4), 1012),
#                                               (datetime.date(2016, 1, 8), 919)],
#  ('A006', 'R079', '00-03-00', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 487),
#                                               (datetime.date(2016, 1, 7), 1350),
#                                               (datetime.date(2016, 1, 2), 786),
#                                               (datetime.date(2016, 1, 6), 1263),
#                                               (datetime.date(2016, 1, 3), 574),
#                                               (datetime.date(2016, 1, 4), 1439),
#                                               (datetime.date(2016, 1, 8), 1313)],
#  ('A006', 'R079', '00-03-01', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 719),
#                                               (datetime.date(2016, 1, 7), 1863),
#                                               (datetime.date(2016, 1, 2), 1004),
#                                               (datetime.date(2016, 1, 6), 1716),
#                                               (datetime.date(2016, 1, 3), 716),
#                                               (datetime.date(2016, 1, 4), 1798),
#                                               (datetime.date(2016, 1, 8), 1744)],
#  ('A006', 'R079', '00-03-02', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 1024),
#                                               (datetime.date(2016, 1, 7), 2382),
#                                               (datetime.date(2016, 1, 2), 1203),
#                                               (datetime.date(2016, 1, 6), 2347),
#                                               (datetime.date(2016, 1, 3), 892),
#                                               (datetime.date(2016, 1, 4), 2364),
#                                               (datetime.date(2016, 1, 8), 2305)],
#  ('A007', 'R079', '01-05-00', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 0),
#                                               (datetime.date(2016, 1, 7), 0),
#                                               (datetime.date(2016, 1, 2), 0),
#                                               (datetime.date(2016, 1, 6), 0),
#                                               (datetime.date(2016, 1, 3), 2),
#                                               (datetime.date(2016, 1, 4), 0),
#                                               (datetime.date(2016, 1, 8), 2)],
#  ('A007', 'R079', '01-05-01', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 0),
#                                               (datetime.date(2016, 1, 7), 0),
#                                               (datetime.date(2016, 1, 2), 0),
#                                               (datetime.date(2016, 1, 6), 0),
#                                               (datetime.date(2016, 1, 3), 0),
#                                               (datetime.date(2016, 1, 4), 0),
#                                               (datetime.date(2016, 1, 8), 0)],
#  ('A007', 'R079', '01-06-00', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 269),
#                                               (datetime.date(2016, 1, 7), 413),
#                                               (datetime.date(2016, 1, 2), 671),
#                                               (datetime.date(2016, 1, 6), 403),
#                                               (datetime.date(2016, 1, 3), 472),
#                                               (datetime.date(2016, 1, 4), 390),
#                                               (datetime.date(2016, 1, 8), 461)],
#  ('A007', 'R079', '01-06-01', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 1061),
#                                               (datetime.date(2016, 1, 7), 172),
#                                               (datetime.date(2016, 1, 2), 965),
#                                               (datetime.date(2016, 1, 6), 1258),
#                                               (datetime.date(2016, 1, 3), 701),
#                                               (datetime.date(2016, 1, 4), 1242)]}

# %%
#Challenge 4
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)


data['key'] = list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

data['datetime'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
datetime_dict = {}

for index, row in data.iterrows():
	value = row['datetime'], row['ENTRIES']
	key = row['key']

	if key in datetime_dict:
		datetime_dict[key].append(value)

	else:
		datetime_dict[key] = [value]

def CountEachDay(my_list):
	dates = [row[0].date() for row in my_list]
	dates = set(dates)

    # make this a dict?
	result = []
	for date in dates:
		entries = [x[1] for x in my_list if x[0].date () == date]
		result.append((date, max(entries)-min(entries)))

	return result

count_dict = {key:CountEachDay(datetime_dict[key]) for key in datetime_dict}
#pprint.pprint(count_dict, width = 100)
#.to_list()
#DEL = pd.DataFrame.from_dict(count_dict, orient='index')
#NewEntryDateList = DEL['0','1'].tolist()
#pprint.pprint(NewEntryDateList)
#pprint.pprint(DEL)
#DEL.head()

def plot_turnstile(dictionary, turnstile_key):
    turnstile_data = sorted(dictionary[turnstile_key])
    
    dates = [x[0] for x in turnstile_data]
    counts = [x[1] for x in turnstile_data]

    plt.figure(figsize=(10,5))
    plt.plot(dates, counts)
    
# Demonstrate
plot_turnstile(count_dict, ('A002', 'R051', '02-00-00', '59 ST'))

# %%
#Challenge 5
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)

#Check this new dictionary
data['key'] = list(zip(data["C/A"], data['UNIT'], data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

data['datetime'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
datetime_dict = {}

for index, row in data.iterrows():
	value = row['datetime'], row['ENTRIES']
	key = row['key']

	if key in datetime_dict:
		datetime_dict[key].append(value)

	else:
		datetime_dict[key] = [value]

def CountEachDay(my_list):
	dates = [row[0].date() for row in my_list]
	dates = set(dates)

    # make this a dict?
	result = []
	for date in dates:
		entries = [x[1] for x in my_list if x[0].date () == date]
		result.append((date, max(entries)-min(entries)))

	return result

count_dict = {key:CountEachDay(datetime_dict[key]) for key in datetime_dict}
pprint.pprint(count_dict, width = 100)

#def plot_turnstile(dictionary, turnstile_key):
 #   turnstile_data = sorted(dictionary[turnstile_key])
    
  #  dates = [x[0] for x in turnstile_data]
   # counts = [x[1] for x in turnstile_data]

    #plt.figure(figsize=(10,5))
    #plt.plot(dates, counts)
    
# Demonstrate
#plot_turnstile(count_dict, ('A002', 'R051', '02-00-00', '59 ST'))
# Out:
# {('A002', 'R051', '59 ST'): [(datetime.date(2016, 1, 5), 8971225),
#                              (datetime.date(2016, 1, 7), 8976972),
#                              (datetime.date(2016, 1, 2), 8964474),
#                              (datetime.date(2016, 1, 6), 8974068),
#                              (datetime.date(2016, 1, 3), 8965996),
#                              (datetime.date(2016, 1, 4), 8968618),
#                              (datetime.date(2016, 1, 8), 8979860)],
#  ('A006', 'R079', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 11643720),
#                                   (datetime.date(2016, 1, 7), 11646097),
#                                   (datetime.date(2016, 1, 2), 11642863),
#                                   (datetime.date(2016, 1, 6), 11645388),
#                                   (datetime.date(2016, 1, 3), 11642775),
#                                   (datetime.date(2016, 1, 4), 11644441),
#                                   (datetime.date(2016, 1, 8), 11646599)],
#  ('A007', 'R079', '5 AV/59 ST'): [(datetime.date(2016, 1, 5), 117732485),
#                                   (datetime.date(2016, 1, 7), 117734248),
#                                   (datetime.date(2016, 1, 2), 117728994),
#                                   (datetime.date(2016, 1, 6), 117733886),
#                                   (datetime.date(2016, 1, 3), 117729865),
#                                   (datetime.date(2016, 1, 4), 117731253),
#                                   (datetime.date(2016, 1, 8), 2797403)]}

# %%
#Challenge 6
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)

#Check this new dictionary
data['key'] = list(zip(data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

data['datetime'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
datetime_dict = {}

for index, row in data.iterrows():
	value = row['datetime'], row['ENTRIES']
	key = row['key']

	if key in datetime_dict:
		datetime_dict[key].append(value)

	else:
		datetime_dict[key] = [value]

def CountEachDay(my_list):
	dates = [row[0].date() for row in my_list]
	dates = set(dates)

    # make this a dict?
	result = []
	for date in dates:
		entries = [x[1] for x in my_list if x[0].date () == date]
		result.append((date, max(entries)-min(entries)))

	return result

count_dict = {key:CountEachDay(datetime_dict[key]) for key in datetime_dict}
pprint.pprint(count_dict, width = 100)

#def plot_turnstile(dictionary, turnstile_key):
 #   turnstile_data = sorted(dictionary[turnstile_key])
    
  #  dates = [x[0] for x in turnstile_data]
   # counts = [x[1] for x in turnstile_data]

    #plt.figure(figsize=(10,5))
    #plt.plot(dates, counts)
    
# Demonstrate
#plot_turnstile(count_dict, ('A002', 'R051', '02-00-00', '59 ST'))
# Out:
# {('5 AV/59 ST',): [(datetime.date(2016, 1, 5), 117732485),
#                    (datetime.date(2016, 1, 7), 117734248),
#                    (datetime.date(2016, 1, 2), 117728994),
#                    (datetime.date(2016, 1, 6), 117733886),
#                    (datetime.date(2016, 1, 3), 117729865),
#                    (datetime.date(2016, 1, 4), 117731253),
#                    (datetime.date(2016, 1, 8), 13219593)],
#  ('59 ST',): [(datetime.date(2016, 1, 5), 8971225),
#               (datetime.date(2016, 1, 7), 8976972),
#               (datetime.date(2016, 1, 2), 8964474),
#               (datetime.date(2016, 1, 6), 8974068),
#               (datetime.date(2016, 1, 3), 8965996),
#               (datetime.date(2016, 1, 4), 8968618),
#               (datetime.date(2016, 1, 8), 8979860)]}

# %%
#Challenge 7
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)

#Check this new dictionary
data['key'] = list(zip(data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

data['datetime'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
datetime_dict = {}

for index, row in data.iterrows():
	value = row['datetime'], row['ENTRIES']
	key = row['key']

	if key in datetime_dict:
		datetime_dict[key].append(value)

	else:
		datetime_dict[key] = [value]

def CountEachDay(my_list):
	dates = [row[0].date() for row in my_list]
	dates = set(dates)

    # make this a dict?
	result = []
	for date in dates:
		entries = [x[1] for x in my_list if x[0].date () == date]
		result.append((date, max(entries)-min(entries)))

	return result

count_dict = {key:CountEachDay(datetime_dict[key]) for key in datetime_dict}
pprint.pprint(count_dict, width = 100)

def plot_turnstile(dictionary, turnstile_key):
    turnstile_data = sorted(dictionary[turnstile_key])
    
    dates = [x[0] for x in turnstile_data]
    counts = [x[1] for x in turnstile_data]

    plt.figure(figsize=(10,5))
    plt.plot(dates, counts)
    
# Demonstrate
plot_turnstile(count_dict, ("5 AV/59 ST,"))
# Out:
# {('5 AV/59 ST',): [(datetime.date(2016, 1, 5), 117732485),
#                    (datetime.date(2016, 1, 7), 117734248),
#                    (datetime.date(2016, 1, 2), 117728994),
#                    (datetime.date(2016, 1, 6), 117733886),
#                    (datetime.date(2016, 1, 3), 117729865),
#                    (datetime.date(2016, 1, 4), 117731253),
#                    (datetime.date(2016, 1, 8), 13219593)],
#  ('59 ST',): [(datetime.date(2016, 1, 5), 8971225),
#               (datetime.date(2016, 1, 7), 8976972),
#               (datetime.date(2016, 1, 2), 8964474),
#               (datetime.date(2016, 1, 6), 8974068),
#               (datetime.date(2016, 1, 3), 8965996),
#               (datetime.date(2016, 1, 4), 8968618),
#               (datetime.date(2016, 1, 8), 8979860)]}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-d37f04722efd> in <module>()
#      54
#      55 # Demonstrate
# ---> 56 plot_turnstile(count_dict, "5 AV/59 ST,")
#      57
#
# <ipython-input-68-d37f04722efd> in plot_turnstile(dictionary, turnstile_key)
#      45
#      46 def plot_turnstile(dictionary, turnstile_key):
# ---> 47     turnstile_data = sorted(dictionary[turnstile_key])
#      48
#      49     dates = [x[0] for x in turnstile_data]
#
# KeyError: '5 AV/59 ST,'
