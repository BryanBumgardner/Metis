# %%
# !head -1000 turnstile_160109.csv > turnshort.csv
#shortens the file so it loads easier. bless up

# %%
#challenge 1

import pandas as pd
import datetime
data = pd.read_csv("turnshort.csv", header=0)

data['key'] = list(zip(data['C/A'], data['UNIT'], data['SCP'], data['STATION']))
#print(list(zip(data['C/A'], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}
#print(data)

# %%
#Challenge 2
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)


data['key'] = list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

data['datetime'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
datetime_dict = {}

for index, row in data.iterrows():
	value = row['datetime'], row['ENTRIES']
	key = row['key']

	if key in datetime_dict:
		datetime_dict[key].append(value)

	else:
		datetime_dict[key] = [value]

def days(my_list):
	dates = [row[0].date() for row in my_list]
	dates = set(dates)

	result = []
	for date in dates:
		entries = [x[1] for x in my_list if x[0].date () == date]
		result.append((date, max(entries)-min(entries)))

	return result

count_dict = {key:days(datetime_dict[key]) for key in datetime_dict}
pprint.pprint(count_dict, width = 100)
# Out:
# {('A002', 'R051', '02-00-00', '59 ST'): [(datetime.date(2016, 1, 8), 1853),
#                                          (datetime.date(2016, 1, 4), 1733),
#                                          (datetime.date(2016, 1, 3), 737),
#                                          (datetime.date(2016, 1, 6), 1733),
#                                          (datetime.date(2016, 1, 7), 1783),
#                                          (datetime.date(2016, 1, 2), 1033),
#                                          (datetime.date(2016, 1, 5), 1596)],
#  ('A002', 'R051', '02-00-01', '59 ST'): [(datetime.date(2016, 1, 8), 1489),
#                                          (datetime.date(2016, 1, 4), 1508),
#                                          (datetime.date(2016, 1, 3), 669),
#                                          (datetime.date(2016, 1, 6), 1459),
#                                          (datetime.date(2016, 1, 7), 1403),
#                                          (datetime.date(2016, 1, 2), 904),
#                                          (datetime.date(2016, 1, 5), 1423)],
#  ('A002', 'R051', '02-03-00', '59 ST'): [(datetime.date(2016, 1, 8), 573),
#                                          (datetime.date(2016, 1, 4), 672),
#                                          (datetime.date(2016, 1, 3), 290),
#                                          (datetime.date(2016, 1, 6), 569),
#                                          (datetime.date(2016, 1, 7), 567),
#                                          (datetime.date(2016, 1, 2), 430),
#                                          (datetime.date(2016, 1, 5), 545)],
#  ('A002', 'R051', '02-03-01', '59 ST'): [(datetime.date(2016, 1, 8), 1338),
#                                          (datetime.date(2016, 1, 4), 1250),
#                                          (datetime.date(2016, 1, 3), 725),
#                                          (datetime.date(2016, 1, 6), 1268),
#                                          (datetime.date(2016, 1, 7), 1328),
#                                          (datetime.date(2016, 1, 2), 991),
#                                          (datetime.date(2016, 1, 5), 1250)],
#  ('A002', 'R051', '02-03-02', '59 ST'): [(datetime.date(2016, 1, 8), 1408),
#                                          (datetime.date(2016, 1, 4), 1305),
#                                          (datetime.date(2016, 1, 3), 657),
#                                          (datetime.date(2016, 1, 6), 1393),
#                                          (datetime.date(2016, 1, 7), 1369),
#                                          (datetime.date(2016, 1, 2), 880),
#                                          (datetime.date(2016, 1, 5), 1258)],
#  ('A002', 'R051', '02-03-03', '59 ST'): [(datetime.date(2016, 1, 8), 1463),
#                                          (datetime.date(2016, 1, 4), 1455),
#                                          (datetime.date(2016, 1, 3), 629),
#                                          (datetime.date(2016, 1, 6), 1406),
#                                          (datetime.date(2016, 1, 7), 1344),
#                                          (datetime.date(2016, 1, 2), 873),
#                                          (datetime.date(2016, 1, 5), 1252)],
#  ('A002', 'R051', '02-03-04', '59 ST'): [(datetime.date(2016, 1, 8), 1771),
#                                          (datetime.date(2016, 1, 4), 1780),
#                                          (datetime.date(2016, 1, 3), 696),
#                                          (datetime.date(2016, 1, 6), 1888),
#                                          (datetime.date(2016, 1, 7), 1730),
#                                          (datetime.date(2016, 1, 2), 1009),
#                                          (datetime.date(2016, 1, 5), 1698)],
#  ('A002', 'R051', '02-03-05', '59 ST'): [(datetime.date(2016, 1, 8), 2745),
#                                          (datetime.date(2016, 1, 4), 2515),
#                                          (datetime.date(2016, 1, 3), 1347),
#                                          (datetime.date(2016, 1, 6), 2726),
#                                          (datetime.date(2016, 1, 7), 2775),
#                                          (datetime.date(2016, 1, 2), 1592),
#                                          (datetime.date(2016, 1, 5), 2482)],
#  ('A002', 'R051', '02-03-06', '59 ST'): [(datetime.date(2016, 1, 8), 2325),
#                                          (datetime.date(2016, 1, 4), 2216),
#                                          (datetime.date(2016, 1, 3), 854),
#                                          (datetime.date(2016, 1, 6), 2388),
#                                          (datetime.date(2016, 1, 7), 2454),
#                                          (datetime.date(2016, 1, 2), 1068),
#                                          (datetime.date(2016, 1, 5), 2263)],
#  ('A002', 'R051', '02-05-00', '59 ST'): [(datetime.date(2016, 1, 8), 0),
#                                          (datetime.date(2016, 1, 4), 0),
#                                          (datetime.date(2016, 1, 3), 1),
#                                          (datetime.date(2016, 1, 6), 0),
#                                          (datetime.date(2016, 1, 7), 0),
#                                          (datetime.date(2016, 1, 2), 0),
#                                          (datetime.date(2016, 1, 5), 0)],
#  ('A002', 'R051', '02-05-01', '59 ST'): [(datetime.date(2016, 1, 8), 0),
#                                          (datetime.date(2016, 1, 4), 0),
#                                          (datetime.date(2016, 1, 3), 0),
#                                          (datetime.date(2016, 1, 6), 0),
#                                          (datetime.date(2016, 1, 7), 0),
#                                          (datetime.date(2016, 1, 2), 0),
#                                          (datetime.date(2016, 1, 5), 0)],
#  ('A002', 'R051', '02-06-00', '59 ST'): [(datetime.date(2016, 1, 8), 2482),
#                                          (datetime.date(2016, 1, 4), 2224),
#                                          (datetime.date(2016, 1, 3), 932),
#                                          (datetime.date(2016, 1, 6), 2444),
#                                          (datetime.date(2016, 1, 7), 2525),
#                                          (datetime.date(2016, 1, 2), 1176),
#                                          (datetime.date(2016, 1, 5), 2174)],
#  ('A006', 'R079', '00-00-00', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 1633),
#                                               (datetime.date(2016, 1, 4), 1596),
#                                               (datetime.date(2016, 1, 3), 786),
#                                               (datetime.date(2016, 1, 6), 1588),
#                                               (datetime.date(2016, 1, 7), 1625),
#                                               (datetime.date(2016, 1, 2), 1116),
#                                               (datetime.date(2016, 1, 5), 1406)],
#  ('A006', 'R079', '00-00-01', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 1638),
#                                               (datetime.date(2016, 1, 4), 1613),
#                                               (datetime.date(2016, 1, 3), 746),
#                                               (datetime.date(2016, 1, 6), 1553),
#                                               (datetime.date(2016, 1, 7), 1585),
#                                               (datetime.date(2016, 1, 2), 1010),
#                                               (datetime.date(2016, 1, 5), 1501)],
#  ('A006', 'R079', '00-00-02', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 1212),
#                                               (datetime.date(2016, 1, 4), 1299),
#                                               (datetime.date(2016, 1, 3), 491),
#                                               (datetime.date(2016, 1, 6), 1233),
#                                               (datetime.date(2016, 1, 7), 1203),
#                                               (datetime.date(2016, 1, 2), 790),
#                                               (datetime.date(2016, 1, 5), 1340)],
#  ('A006', 'R079', '00-00-03', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 940),
#                                               (datetime.date(2016, 1, 4), 1094),
#                                               (datetime.date(2016, 1, 3), 465),
#                                               (datetime.date(2016, 1, 6), 972),
#                                               (datetime.date(2016, 1, 7), 1053),
#                                               (datetime.date(2016, 1, 2), 657),
#                                               (datetime.date(2016, 1, 5), 1543)],
#  ('A006', 'R079', '00-00-04', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 919),
#                                               (datetime.date(2016, 1, 4), 1012),
#                                               (datetime.date(2016, 1, 3), 453),
#                                               (datetime.date(2016, 1, 6), 1007),
#                                               (datetime.date(2016, 1, 7), 952),
#                                               (datetime.date(2016, 1, 2), 668),
#                                               (datetime.date(2016, 1, 5), 650)],
#  ('A006', 'R079', '00-03-00', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 1313),
#                                               (datetime.date(2016, 1, 4), 1439),
#                                               (datetime.date(2016, 1, 3), 574),
#                                               (datetime.date(2016, 1, 6), 1263),
#                                               (datetime.date(2016, 1, 7), 1350),
#                                               (datetime.date(2016, 1, 2), 786),
#                                               (datetime.date(2016, 1, 5), 487)],
#  ('A006', 'R079', '00-03-01', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 1744),
#                                               (datetime.date(2016, 1, 4), 1798),
#                                               (datetime.date(2016, 1, 3), 716),
#                                               (datetime.date(2016, 1, 6), 1716),
#                                               (datetime.date(2016, 1, 7), 1863),
#                                               (datetime.date(2016, 1, 2), 1004),
#                                               (datetime.date(2016, 1, 5), 719)],
#  ('A006', 'R079', '00-03-02', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 2305),
#                                               (datetime.date(2016, 1, 4), 2364),
#                                               (datetime.date(2016, 1, 3), 892),
#                                               (datetime.date(2016, 1, 6), 2347),
#                                               (datetime.date(2016, 1, 7), 2382),
#                                               (datetime.date(2016, 1, 2), 1203),
#                                               (datetime.date(2016, 1, 5), 1024)],
#  ('A007', 'R079', '01-05-00', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 2),
#                                               (datetime.date(2016, 1, 4), 0),
#                                               (datetime.date(2016, 1, 3), 2),
#                                               (datetime.date(2016, 1, 6), 0),
#                                               (datetime.date(2016, 1, 7), 0),
#                                               (datetime.date(2016, 1, 2), 0),
#                                               (datetime.date(2016, 1, 5), 0)],
#  ('A007', 'R079', '01-05-01', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 0),
#                                               (datetime.date(2016, 1, 4), 0),
#                                               (datetime.date(2016, 1, 3), 0),
#                                               (datetime.date(2016, 1, 6), 0),
#                                               (datetime.date(2016, 1, 7), 0),
#                                               (datetime.date(2016, 1, 2), 0),
#                                               (datetime.date(2016, 1, 5), 0)],
#  ('A007', 'R079', '01-06-00', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 461),
#                                               (datetime.date(2016, 1, 4), 390),
#                                               (datetime.date(2016, 1, 3), 472),
#                                               (datetime.date(2016, 1, 6), 403),
#                                               (datetime.date(2016, 1, 7), 413),
#                                               (datetime.date(2016, 1, 2), 671),
#                                               (datetime.date(2016, 1, 5), 269)],
#  ('A007', 'R079', '01-06-01', '5 AV/59 ST'): [(datetime.date(2016, 1, 4), 1242),
#                                               (datetime.date(2016, 1, 3), 701),
#                                               (datetime.date(2016, 1, 6), 1258),
#                                               (datetime.date(2016, 1, 7), 172),
#                                               (datetime.date(2016, 1, 2), 965),
#                                               (datetime.date(2016, 1, 5), 1061)]}

# %%
#Challenge 2
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)

data['key'] = list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

# %%
data

# %%
#Challenge 3
# n = 4
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)


data['key'] = list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

data['datetime'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
datetime_dict = {}

for index, row in data.iterrows():
	value = row['datetime'], row['ENTRIES']
	key = row['key']

	if key in datetime_dict:
		datetime_dict[key].append(value)

	else:
		datetime_dict[key] = [value]

def CountEachDay(my_list):
	dates = [row[0].date() for row in my_list]
	dates = set(dates)

	result = []
	for date in dates:
		entries = [x[1] for x in my_list if x[0].date () == date]
		result.append((date, max(entries)-min(entries)))

	return result

count_dict = {key:CountEachDay(datetime_dict[key]) for key in datetime_dict}
pprint.pprint(count_dict, width = 100)

# %%
#Challenge 4
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)


data['key'] = list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

data['datetime'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
datetime_dict = {}

for index, row in data.iterrows():
	value = row['datetime'], row['ENTRIES']
	key = row['key']

	if key in datetime_dict:
		datetime_dict[key].append(value)

	else:
		datetime_dict[key] = [value]

def CountEachDay(my_list):
	dates = [row[0].date() for row in my_list]
	dates = set(dates)

    # make this a dict?
	result = []
	for date in dates:
		entries = [x[1] for x in my_list if x[0].date () == date]
		result.append((date, max(entries)-min(entries)))

	return result

count_dict = {key:CountEachDay(datetime_dict[key]) for key in datetime_dict}
#pprint.pprint(count_dict, width = 100)
#.to_list()
#DEL = pd.DataFrame.from_dict(count_dict, orient='index')
#NewEntryDateList = DEL['0','1'].tolist()
#pprint.pprint(NewEntryDateList)
#pprint.pprint(DEL)
#DEL.head()

def plot_turnstile(dictionary, turnstile_key):
    turnstile_data = sorted(dictionary[turnstile_key])
    
    dates = [x[0] for x in turnstile_data]
    counts = [x[1] for x in turnstile_data]

    plt.figure(figsize=(10,5))
    plt.plot(dates, counts)
    
# Demonstrate
plot_turnstile(count_dict, ('A002', 'R051', '02-00-00', '59 ST'))

# %%
#Challenge 5
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)

#Check this new dictionary
data['key'] = list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

data['datetime'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
datetime_dict = {}

for index, row in data.iterrows():
	value = row['datetime'], row['ENTRIES']
	key = row['key']

	if key in datetime_dict:
		datetime_dict[key].append(value)

	else:
		datetime_dict[key] = [value]

def CountEachDay(my_list):
	dates = [row[0].date() for row in my_list]
	dates = set(dates)

    # make this a dict?
	result = []
	for date in dates:
		entries = [x[1] for x in my_list if x[0].date () == date]
		result.append((date, max(entries)-min(entries)))

	return result

count_dict = {key:CountEachDay(datetime_dict[key]) for key in datetime_dict}
pprint.pprint(count_dict, width = 100)

#def plot_turnstile(dictionary, turnstile_key):
 #   turnstile_data = sorted(dictionary[turnstile_key])
    
  #  dates = [x[0] for x in turnstile_data]
   # counts = [x[1] for x in turnstile_data]

    #plt.figure(figsize=(10,5))
    #plt.plot(dates, counts)
    
# Demonstrate
#plot_turnstile(count_dict, ('A002', 'R051', '02-00-00', '59 ST'))
# Out:
# {('A002', 'R051', '02-00-00', '59 ST'): [(datetime.date(2016, 1, 8), 1853),
#                                          (datetime.date(2016, 1, 4), 1733),
#                                          (datetime.date(2016, 1, 3), 737),
#                                          (datetime.date(2016, 1, 6), 1733),
#                                          (datetime.date(2016, 1, 7), 1783),
#                                          (datetime.date(2016, 1, 2), 1033),
#                                          (datetime.date(2016, 1, 5), 1596)],
#  ('A002', 'R051', '02-00-01', '59 ST'): [(datetime.date(2016, 1, 8), 1489),
#                                          (datetime.date(2016, 1, 4), 1508),
#                                          (datetime.date(2016, 1, 3), 669),
#                                          (datetime.date(2016, 1, 6), 1459),
#                                          (datetime.date(2016, 1, 7), 1403),
#                                          (datetime.date(2016, 1, 2), 904),
#                                          (datetime.date(2016, 1, 5), 1423)],
#  ('A002', 'R051', '02-03-00', '59 ST'): [(datetime.date(2016, 1, 8), 573),
#                                          (datetime.date(2016, 1, 4), 672),
#                                          (datetime.date(2016, 1, 3), 290),
#                                          (datetime.date(2016, 1, 6), 569),
#                                          (datetime.date(2016, 1, 7), 567),
#                                          (datetime.date(2016, 1, 2), 430),
#                                          (datetime.date(2016, 1, 5), 545)],
#  ('A002', 'R051', '02-03-01', '59 ST'): [(datetime.date(2016, 1, 8), 1338),
#                                          (datetime.date(2016, 1, 4), 1250),
#                                          (datetime.date(2016, 1, 3), 725),
#                                          (datetime.date(2016, 1, 6), 1268),
#                                          (datetime.date(2016, 1, 7), 1328),
#                                          (datetime.date(2016, 1, 2), 991),
#                                          (datetime.date(2016, 1, 5), 1250)],
#  ('A002', 'R051', '02-03-02', '59 ST'): [(datetime.date(2016, 1, 8), 1408),
#                                          (datetime.date(2016, 1, 4), 1305),
#                                          (datetime.date(2016, 1, 3), 657),
#                                          (datetime.date(2016, 1, 6), 1393),
#                                          (datetime.date(2016, 1, 7), 1369),
#                                          (datetime.date(2016, 1, 2), 880),
#                                          (datetime.date(2016, 1, 5), 1258)],
#  ('A002', 'R051', '02-03-03', '59 ST'): [(datetime.date(2016, 1, 8), 1463),
#                                          (datetime.date(2016, 1, 4), 1455),
#                                          (datetime.date(2016, 1, 3), 629),
#                                          (datetime.date(2016, 1, 6), 1406),
#                                          (datetime.date(2016, 1, 7), 1344),
#                                          (datetime.date(2016, 1, 2), 873),
#                                          (datetime.date(2016, 1, 5), 1252)],
#  ('A002', 'R051', '02-03-04', '59 ST'): [(datetime.date(2016, 1, 8), 1771),
#                                          (datetime.date(2016, 1, 4), 1780),
#                                          (datetime.date(2016, 1, 3), 696),
#                                          (datetime.date(2016, 1, 6), 1888),
#                                          (datetime.date(2016, 1, 7), 1730),
#                                          (datetime.date(2016, 1, 2), 1009),
#                                          (datetime.date(2016, 1, 5), 1698)],
#  ('A002', 'R051', '02-03-05', '59 ST'): [(datetime.date(2016, 1, 8), 2745),
#                                          (datetime.date(2016, 1, 4), 2515),
#                                          (datetime.date(2016, 1, 3), 1347),
#                                          (datetime.date(2016, 1, 6), 2726),
#                                          (datetime.date(2016, 1, 7), 2775),
#                                          (datetime.date(2016, 1, 2), 1592),
#                                          (datetime.date(2016, 1, 5), 2482)],
#  ('A002', 'R051', '02-03-06', '59 ST'): [(datetime.date(2016, 1, 8), 2325),
#                                          (datetime.date(2016, 1, 4), 2216),
#                                          (datetime.date(2016, 1, 3), 854),
#                                          (datetime.date(2016, 1, 6), 2388),
#                                          (datetime.date(2016, 1, 7), 2454),
#                                          (datetime.date(2016, 1, 2), 1068),
#                                          (datetime.date(2016, 1, 5), 2263)],
#  ('A002', 'R051', '02-05-00', '59 ST'): [(datetime.date(2016, 1, 8), 0),
#                                          (datetime.date(2016, 1, 4), 0),
#                                          (datetime.date(2016, 1, 3), 1),
#                                          (datetime.date(2016, 1, 6), 0),
#                                          (datetime.date(2016, 1, 7), 0),
#                                          (datetime.date(2016, 1, 2), 0),
#                                          (datetime.date(2016, 1, 5), 0)],
#  ('A002', 'R051', '02-05-01', '59 ST'): [(datetime.date(2016, 1, 8), 0),
#                                          (datetime.date(2016, 1, 4), 0),
#                                          (datetime.date(2016, 1, 3), 0),
#                                          (datetime.date(2016, 1, 6), 0),
#                                          (datetime.date(2016, 1, 7), 0),
#                                          (datetime.date(2016, 1, 2), 0),
#                                          (datetime.date(2016, 1, 5), 0)],
#  ('A002', 'R051', '02-06-00', '59 ST'): [(datetime.date(2016, 1, 8), 2482),
#                                          (datetime.date(2016, 1, 4), 2224),
#                                          (datetime.date(2016, 1, 3), 932),
#                                          (datetime.date(2016, 1, 6), 2444),
#                                          (datetime.date(2016, 1, 7), 2525),
#                                          (datetime.date(2016, 1, 2), 1176),
#                                          (datetime.date(2016, 1, 5), 2174)],
#  ('A006', 'R079', '00-00-00', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 1633),
#                                               (datetime.date(2016, 1, 4), 1596),
#                                               (datetime.date(2016, 1, 3), 786),
#                                               (datetime.date(2016, 1, 6), 1588),
#                                               (datetime.date(2016, 1, 7), 1625),
#                                               (datetime.date(2016, 1, 2), 1116),
#                                               (datetime.date(2016, 1, 5), 1406)],
#  ('A006', 'R079', '00-00-01', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 1638),
#                                               (datetime.date(2016, 1, 4), 1613),
#                                               (datetime.date(2016, 1, 3), 746),
#                                               (datetime.date(2016, 1, 6), 1553),
#                                               (datetime.date(2016, 1, 7), 1585),
#                                               (datetime.date(2016, 1, 2), 1010),
#                                               (datetime.date(2016, 1, 5), 1501)],
#  ('A006', 'R079', '00-00-02', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 1212),
#                                               (datetime.date(2016, 1, 4), 1299),
#                                               (datetime.date(2016, 1, 3), 491),
#                                               (datetime.date(2016, 1, 6), 1233),
#                                               (datetime.date(2016, 1, 7), 1203),
#                                               (datetime.date(2016, 1, 2), 790),
#                                               (datetime.date(2016, 1, 5), 1340)],
#  ('A006', 'R079', '00-00-03', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 940),
#                                               (datetime.date(2016, 1, 4), 1094),
#                                               (datetime.date(2016, 1, 3), 465),
#                                               (datetime.date(2016, 1, 6), 972),
#                                               (datetime.date(2016, 1, 7), 1053),
#                                               (datetime.date(2016, 1, 2), 657),
#                                               (datetime.date(2016, 1, 5), 1543)],
#  ('A006', 'R079', '00-00-04', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 919),
#                                               (datetime.date(2016, 1, 4), 1012),
#                                               (datetime.date(2016, 1, 3), 453),
#                                               (datetime.date(2016, 1, 6), 1007),
#                                               (datetime.date(2016, 1, 7), 952),
#                                               (datetime.date(2016, 1, 2), 668),
#                                               (datetime.date(2016, 1, 5), 650)],
#  ('A006', 'R079', '00-03-00', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 1313),
#                                               (datetime.date(2016, 1, 4), 1439),
#                                               (datetime.date(2016, 1, 3), 574),
#                                               (datetime.date(2016, 1, 6), 1263),
#                                               (datetime.date(2016, 1, 7), 1350),
#                                               (datetime.date(2016, 1, 2), 786),
#                                               (datetime.date(2016, 1, 5), 487)],
#  ('A006', 'R079', '00-03-01', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 1744),
#                                               (datetime.date(2016, 1, 4), 1798),
#                                               (datetime.date(2016, 1, 3), 716),
#                                               (datetime.date(2016, 1, 6), 1716),
#                                               (datetime.date(2016, 1, 7), 1863),
#                                               (datetime.date(2016, 1, 2), 1004),
#                                               (datetime.date(2016, 1, 5), 719)],
#  ('A006', 'R079', '00-03-02', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 2305),
#                                               (datetime.date(2016, 1, 4), 2364),
#                                               (datetime.date(2016, 1, 3), 892),
#                                               (datetime.date(2016, 1, 6), 2347),
#                                               (datetime.date(2016, 1, 7), 2382),
#                                               (datetime.date(2016, 1, 2), 1203),
#                                               (datetime.date(2016, 1, 5), 1024)],
#  ('A007', 'R079', '01-05-00', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 2),
#                                               (datetime.date(2016, 1, 4), 0),
#                                               (datetime.date(2016, 1, 3), 2),
#                                               (datetime.date(2016, 1, 6), 0),
#                                               (datetime.date(2016, 1, 7), 0),
#                                               (datetime.date(2016, 1, 2), 0),
#                                               (datetime.date(2016, 1, 5), 0)],
#  ('A007', 'R079', '01-05-01', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 0),
#                                               (datetime.date(2016, 1, 4), 0),
#                                               (datetime.date(2016, 1, 3), 0),
#                                               (datetime.date(2016, 1, 6), 0),
#                                               (datetime.date(2016, 1, 7), 0),
#                                               (datetime.date(2016, 1, 2), 0),
#                                               (datetime.date(2016, 1, 5), 0)],
#  ('A007', 'R079', '01-06-00', '5 AV/59 ST'): [(datetime.date(2016, 1, 8), 461),
#                                               (datetime.date(2016, 1, 4), 390),
#                                               (datetime.date(2016, 1, 3), 472),
#                                               (datetime.date(2016, 1, 6), 403),
#                                               (datetime.date(2016, 1, 7), 413),
#                                               (datetime.date(2016, 1, 2), 671),
#                                               (datetime.date(2016, 1, 5), 269)],
#  ('A007', 'R079', '01-06-01', '5 AV/59 ST'): [(datetime.date(2016, 1, 4), 1242),
#                                               (datetime.date(2016, 1, 3), 701),
#                                               (datetime.date(2016, 1, 6), 1258),
#                                               (datetime.date(2016, 1, 7), 172),
#                                               (datetime.date(2016, 1, 2), 965),
#                                               (datetime.date(2016, 1, 5), 1061)]}

# %%
#Challenge 6
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)

#Check this new dictionary
data['key'] = list(zip(data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

data['datetime'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
datetime_dict = {}

for index, row in data.iterrows():
	value = row['datetime'], row['ENTRIES']
	key = row['key']

	if key in datetime_dict:
		datetime_dict[key].append(value)

	else:
		datetime_dict[key] = [value]

def CountEachDay(my_list):
	dates = [row[0].date() for row in my_list]
	dates = set(dates)

    # make this a dict?
	result = []
	for date in dates:
		entries = [x[1] for x in my_list if x[0].date () == date]
		result.append((date, max(entries)-min(entries)))

	return result

count_dict = {key:CountEachDay(datetime_dict[key]) for key in datetime_dict}
pprint.pprint(count_dict, width = 100)

#def plot_turnstile(dictionary, turnstile_key):
 #   turnstile_data = sorted(dictionary[turnstile_key])
    
  #  dates = [x[0] for x in turnstile_data]
   # counts = [x[1] for x in turnstile_data]

    #plt.figure(figsize=(10,5))
    #plt.plot(dates, counts)
    
# Demonstrate
#plot_turnstile(count_dict, ('A002', 'R051', '02-00-00', '59 ST'))

# %%
#Challenge 7
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data1 = pd.read_csv("turnshort.csv", header=0)
data2 = 

def ex_fnn(data):
    #Check this new dictionary
    data['key'] = list(zip(data['STATION']))
    #print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
    data_dict = {}

    data['datetime'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
    datetime_dict = {}

    for index, row in data.iterrows():
        value = row['datetime'], row['ENTRIES']
        key = row['key']

        if key in datetime_dict:
            datetime_dict[key].append(value)

        else:
            datetime_dict[key] = [value]

    return(datetime_dict)

data1 = pd.read_csv("turnshort.csv", header=0)
data2 = 
#ex

def next_fun(data):
    count_dict = {key:CountEachDay(datetime_dict[key]) for key in datetime_dict}
    #pprint.pprint(count_dict, width = 100)
    return count_dict

def run(data):
    #runs all code
    datetime_dict1 = ex_fnn(data)
    count_dict = next_fun(datetime_dict1)

    
def CountEachDay(my_list):
	dates = [row[0].date() for row in my_list]
	dates = set(dates)

    # make this a dict?
	result = []
	for date in dates:
		entries = [x[1] for x in my_list if x[0].date () == date]
		result.append((date, max(entries)-min(entries)))

	return result

count_dict = {key:CountEachDay(datetime_dict[key]) for key in datetime_dict}
#pprint.pprint(count_dict, width = 100)

def plot_turnstile(dictionary, turnstile_key):
    turnstile_data = sorted(dictionary[turnstile_key])
    
    dates = [x[0] for x in turnstile_data]
    counts = [x[1] for x in turnstile_data]

    plt.figure(figsize=(10,5))
    plt.plot(dates, counts)
    
key = ('5 AV/59 ST',)
# Demonstrate
plot_turnstile(count_dict, key)

key = ('59 ST',)
# Demonstrate
plot_turnstile(count_dict, key)



count_dict1 = run(data1)
for key in count_dict1.keys():
    # Demonstrate
    plot_turnstile(count_dict1, key)

# %%
count_dict.keys()

# %%
key

# %%
sorted(count_dict[key])

# %%
#Challenge 8
#Challenge 7
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import pprint
import datetime

data = pd.read_csv("turnshort.csv", header=0)

#Check this new dictionary
data['key'] = list(zip(data['STATION']))
#print(list(zip(data["C/A"], data['UNIT'], data['SCP'], data['STATION'])))
data_dict = {}

data['datetime'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
datetime_dict = {}

for index, row in data.iterrows():
	value = row['datetime'], row['ENTRIES']
	key = row['key']

	if key in datetime_dict:
		datetime_dict[key].append(value)

	else:
		datetime_dict[key] = [value]

def CountEachDay(my_list):
	dates = [row[0].date() for row in my_list]
	dates = set(dates)

    # make this a dict?
	result = []
	for date in dates:
		entries = [x[1] for x in my_list if x[0].date () == date]
		result.append((date, max(entries)-min(entries)))

	return result

count_dict = {key:CountEachDay(datetime_dict[key]) for key in datetime_dict}



pprint.pprint(count_dict, width = 100)

#def plot_turnstile(dictionary, turnstile_key):
 #   turnstile_data = sorted(dictionary[turnstile_key])
    
  #  dates = [x[0] for x in turnstile_data]
   # counts = [x[1] for x in turnstile_data]

    #plt.figure(figsize=(10,5))
    #plt.plot(dates, counts)
    
# Demonstrate
# plot_turnstile(count_dict)
